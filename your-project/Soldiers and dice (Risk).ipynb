# %% [markdown]
# # Risk

# %%
# Important rules
# 
# 
# Minimum 2 players
# Rounds, no max
# Winner World domination
# Every round new army
# Roll the dice, max (A=3, D=2), tie-> D wins
# Simplified with 10 countries
# random assigned countries

# Strategy
# while loop until x amount of wins

# %%
import random

# %%
# Roll the dice
# 2 Inputs: amount of armies, attack 1/2/3 and defence 1/2
# 2 Outputs, armies left 


def roll_the_dice(x,y):
    if (x == 3) & (y == 2):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        x_dice_2= random.randrange(1,7,1)
        x_dice_3= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        y_dice_2= random.randrange(1,7,1)
        if (x_dice > y_dice) & (x_dice_2 > y_dice) & (x_dice_3 > y_dice):
            if (x_dice > y_dice_2) & (x_dice_2 > y_dice_2) & (x_dice_3 > y_dice_2):
                print("Attack wins")
                new_x=3
                new_y=0
            elif (x_dice <= y_dice_2) & (x_dice_2 <= y_dice_2) & (x_dice_3 <= y_dice_2):
                print("Draw")
                new_x= 2
                new_y= 1
            elif (x_dice <= y_dice_2) | (x_dice_2 <= y_dice_2) | (x_dice_3 <= y_dice_2):
                if (x_dice_2 <= y_dice_2) | (x_dice_3 <= y_dice_2):
                    print("Draw")
                    new_x= 2
                    new_y= 1
                     
                                       
        elif (x_dice > y_dice_2) & (x_dice_2 > y_dice_2) & (x_dice_3 > y_dice_2):
            if (x_dice > y_dice) & (x_dice_2 > y_dice) & (x_dice_3 > y_dice):
                print("Attack wins")
                new_x=3
                new_y=0
            elif (x_dice <= y_dice) & (x_dice_2 <= y_dice) & (x_dice_3 <= y_dice):
                print("Draw")
                new_x= 2
                new_y= 1
            elif (x_dice <= y_dice) | (x_dice_2 <= y_dice) | (x_dice_3 <= y_dice):
                if (x_dice_2 <= y_dice) | (x_dice_3 <= y_dice):
                    print("Draw")
                    new_x= 2
                    new_y= 1
                     
       
        
        elif (x_dice <= y_dice) & (x_dice_2 <= y_dice) & (x_dice_3 <= y_dice):
            if (x_dice <= y_dice_2) & (x_dice_2 <= y_dice_2) & (x_dice_3 <= y_dice_2):
                print("Defence wins")
                new_x= 1
                new_y= 2
            elif (x_dice <= y_dice_2) | (x_dice_2 <= y_dice_2) | (x_dice_3 <= y_dice_2):
                if (x_dice <= y_dice_2) & (x_dice_2 <= y_dice_2):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                elif (x_dice <= y_dice_2) & (x_dice_3 <= y_dice_2):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                elif (x_dice_2 <= y_dice_2) & (x_dice_3 <= y_dice_2):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                else:
                    print("Draw")
                    new_x=1
                    new_y=1
                
  
        elif (x_dice <= y_dice_2) & (x_dice_2 <= y_dice_2) & (x_dice_3 <= y_dice_2):
            if (x_dice <= y_dice) & (x_dice_2 <= y_dice) & (x_dice_3 <= y_dice):
                print("Defence wins")
                new_x= 1
                new_y= 2
            elif (x_dice <= y_dice) | (x_dice_2 <= y_dice) | (x_dice_3 <= y_dice):
                if (x_dice <= y_dice) & (x_dice_2 <= y_dice):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                elif (x_dice <= y_dice) & (x_dice_3 <= y_dice):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                elif (x_dice_2 <= y_dice) & (x_dice_3 <= y_dice):
                    print("Defence wins")
                    new_x=1
                    new_y=2
                else:
                    print("Draw")
                    new_x=1
                    new_y=1
        
        elif (x_dice > y_dice) | (x_dice_2 > y_dice) | (x_dice_3 > y_dice):
            if y_dice > y_dice_2:            
                if (x_dice > y_dice):
                    print("Attack wins at least one")
                    if (x_dice_2 > y_dice_2) | (x_dice_3 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
            
                if (x_dice_2 > y_dice):
                    print("Attack wins at least one")
                    if (x_dice > y_dice_2) | (x_dice_3 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                               
                if (x_dice_3 > y_dice):
                    print("Attack wins at least one")
                    if (x_dice > y_dice_2) | (x_dice_2 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
            
            
            elif y_dice < y_dice_2:
                if (x_dice > y_dice_2):
                    print("Attack wins at least one")
                    if (x_dice_2 > y_dice) | (x_dice_3 > y_dice):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                    
                if (x_dice_2 > y_dice_2):
                    print("Attack wins at least one")
                    if (x_dice > y_dice) | (x_dice_3 > y_dice):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                        
                if (x_dice_3 > y_dice_2):
                    print("Attack wins at least one")
                    if (x_dice > y_dice) | (x_dice_2 > y_dice):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                        
            elif y_dice == y_dice_2:
                if (x_dice > y_dice):
                    print("Attack wins at least one")
                    if (x_dice_2 > y_dice_2) | (x_dice_3 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
            
                if (x_dice_2 > y_dice):
                    print("Attack wins at least one")
                    if (x_dice > y_dice_2) | (x_dice_3 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                               
                if (x_dice_3 > y_dice):
                    print("Attack wins at least one")
                    if (x_dice > y_dice_2) | (x_dice_2 > y_dice_2):
                        print("Attack wins")
                        new_x= 3
                        new_y= 0
                        
                    else:
                        print("Draw")
                        new_x= 2
                        new_y= 1
                
                       
        else:
            print("test")
                 
             
    elif (x== 3) & (y == 1):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        x_dice_2= random.randrange(1,7,1)
        x_dice_3= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        if(x_dice > y_dice) | (x_dice_2 > y_dice) | (x_dice_3 > y_dice):
            print("Attack wins")
            new_x= 3
            new_y=0
        elif (y_dice >= x_dice) & (y_dice >= x_dice_2) & (y_dice >= x_dice_3):
            print("Defence wins")
            new_x=2
            new_y=1
        
        
    elif (x == 2) & (y == 2):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        x_dice_2= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        y_dice_2= random.randrange(1,7,1)
        if (x_dice > y_dice) & (x_dice > y_dice_2):
            print("First attack wins")
            if (x_dice_2 > y_dice) & (x_dice_2 > y_dice_2):
                print("Attack wins")
                new_x= 2
                new_y= 0
            elif (x_dice_2 <= y_dice) & (x_dice_2 <= y_dice_2):
                print("Draw")
                new_x=1
                new_y=1
            elif (x_dice_2 > y_dice) | (x_dice_2 > y_dice_2):
                print("Attack wins")
                new_x=2
                new_y=0
        if (x_dice_2 > y_dice) & (x_dice_2 > y_dice_2):
            print("Second attack wins")
            if x_dice > y_dice & x_dice > y_dice_2:
                print("Attack wins")
                new_x= 2
                new_y= 0
            elif (x_dice <= y_dice) & (x_dice <= y_dice_2):
                print("Draw")
                new_x=1
                new_y=1
            elif (x_dice > y_dice) | (x_dice > y_dice_2):
                print("Attack wins")
                new_x=2
                new_y=0
                                    
    elif (x == 2) & (y == 1):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        x_dice_2= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        if x_dice > y_dice | x_dice_2 > y_dice:
            print("Attack wins")
            new_x= 2
            new_y= 0
        elif y_dice >= x_dice & y_dice >= x_dice_2:
            print("Defence wins")
            new_x=1
            new_y=1
                                  
    elif (x== 1) & (y ==1):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        if (x_dice) > (y_dice):
            print("Attack wins")
            new_x= 1
            new_y=0
            
        elif (y_dice) >= (x_dice):
            print("Defence wins")
            new_x=0
            new_y=1  
                                     
    elif (x == 1) & (y == 2):
        new_x=[]
        new_y=[]
        x_dice= random.randrange(1,7,1)
        y_dice= random.randrange(1,7,1)
        y_dice_2= random.randrange(1,7,1)
        if x_dice > y_dice & x_dice > y_dice_2:
            print("Attack wins")
            new_x= 1
            new_y= 1
        elif y_dice >= x_dice | y_dice_2 >= x_dice:
            print("Defence wins")
            new_x=0
            new_y=2
          
    else:
        print("Nothing happens")
        
    
    return new_x,new_y

# %%
attack= int(input("How many attack: "))
while attack > 3:
    attack = int(input("How many attack?: "))
    
defence= int(input("How many defence?: "))
while defence > 2:
    defence= int(input("How many defence?: "))

    
roll_the_dice(attack,defence)
print(type(roll_the_dice(attack,defence)))
# Out:
# How many attack: 3
# How many defence?: 1
# Attack wins
# Attack wins
# <class 'tuple'>

# %%
# max_wins = 10
# print("Let's play!")
# while x < max_wins

# %%
#Play until pl1 wins or has 0
# only one attack permitted per round

max_wins = 10
total_c= 2
c_p1=1
a_p1=20
c_p2=1
a_p2=20


# Start of the game
total_rounds=0
# armies are equally divided, -1

while c_p1 < max_wins:
    total_rounds += 1
    a_p1 += 5
    total_a_c_p1= a_p1/c_p1
    a_p2 += 5
    total_a_c_p2= a_p2/c_p2
    print("Player 1 starts")
    if total_a_c_p1 >= 4:
        attack= int(input("How many attack: "))
        while attack > 3:
            attack = int(input("How many attack?: "))
    
        defence= int(input("How many defence?: "))
        while defence > 2:
            defence= int(input("How many defence?: "))
    total_a_c_p1 += (roll_the_dice(attack,defence))
    print(total_a_c_p1)
     
    
    
 
    
    
    
# else:
#     print("Player 1, you can't attack")
#     print("Player 2, it's your turn")
# Out:
# Player 1 starts
